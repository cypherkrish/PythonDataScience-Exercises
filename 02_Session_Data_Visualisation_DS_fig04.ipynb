# %% [markdown]
# <a href="https://colab.research.google.com/github/cypherkrish/PythonDataScience-Exercises/blob/main/02_Session_Data_Visualisation_DS_fig04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import warnings
import datetime as dt
warnings.filterwarnings('ignore')

# %%
dfm = pd.read_csv('https://raw.githubusercontent.com/cypherkrish/PythonDataScience/main/Data/matchs.csv')
dfd = pd.read_csv('https://raw.githubusercontent.com/cypherkrish/PythonDataScience/main/Data/deliveris.csv')

# %% [markdown]
# Draw a histogram plot on runs scored by batsmen on each match with respect to number of times .
# - Hint- For getting batsmen runs on each match sum batsmen runs with respect to match id.
# Expected Plot

# %%
fig4,ax4=plt.subplots(figsize=(15,8))
###Start code here
#data_fig4 = dfd.groupby(['match_id', 'batsman'])['batsman_runs'].sum().reset_index()['batsman_runs'].value_counts().reset_index()
data_fig4 = dfd.groupby(['match_id', 'batsman'])['batsman_runs'].sum()
ax4.hist(data_fig4 , color='lightblue', edgecolor='white')
ax4.set_title('Histogram for Runs Scored', fontsize=16)
ax4.set_xlabel('Runs Scored')#, fontsize=14)
ax4.set_ylabel('Number of Times') #, fontsize=14)

# Show the plot
plt.show()
