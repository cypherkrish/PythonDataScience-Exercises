# %% [markdown]
# <a href="https://colab.research.google.com/github/cypherkrish/PythonDataScience-Exercises/blob/main/02_Session_Data_Visualisation_DS_fig05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import warnings
import datetime as dt
warnings.filterwarnings('ignore')

# %%
dfm = pd.read_csv('https://raw.githubusercontent.com/cypherkrish/PythonDataScience/main/Data/matchs.csv')
dfd = pd.read_csv('https://raw.githubusercontent.com/cypherkrish/PythonDataScience/main/Data/deliveris.csv')

# %% [markdown]
# Draw a scatter plot on runs scored by batsmen on each match with respect to balls faced .
# - Minimum number of balls faced should be greater than 20
# Expected Plot

# %%
fig5,ax5=plt.subplots(figsize=(15,8))
###Start code here
data_ballsFaced_RunsScored = dfd.groupby(['match_id', 'batsman'])[['ball', 'batsman_runs']].agg(['size', 'sum']).reset_index()
dic = {}
balls_faced = list(data_ballsFaced_RunsScored['ball']['size'])
runs_scored = list (data_ballsFaced_RunsScored['batsman_runs']['sum'])
dic['match_id'] = list(data_ballsFaced_RunsScored['match_id'])
dic['batsman'] = list(data_ballsFaced_RunsScored['batsman'])
dic['balls_faced'] = balls_faced
dic['runs_scored'] = runs_scored
result = pd.DataFrame(dic)


result_filter = result[result['balls_faced'] > 20]
sns.scatterplot(data=result_filter, x="balls_faced", y="runs_scored")
#ax5.scatter(result_filter['ball'], result_filter['batsman_runs'])#, color='blue', s=5)
ax5.set_title('Runs Scored vs Balls Faced') #, fontsize=16)
#ax5.set_xlim(10,)
ax5.set_xlabel('Balls Faced', fontsize=14)
ax5.set_ylabel('Runs Scored', fontsize=14)
plt.show()
